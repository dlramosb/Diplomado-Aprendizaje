# %% [markdown]
# # La nostalgia del Melómano
#
# Este es un libro para prueba
#
# [Venta en amazon](https://www.amazon.com/-/es/Juan-Carlos-Garay-ebook/dp/B08HS732G9/ref=sr_1_1?__mk_es_US=%C3%85M%C3%85%C5%BD%C3%95%C3%91&dchild=1&keywords=la+nostalgia+del+melomano&qid=1614815138&sr=8-1)
#
# [¿Como Aprender Markdown?](https://www.markdownguide.org/basic-syntax/)
#
# ![Imagen](data:image/jpeg;base64,...)

# %% [markdown]
# ## Capitulo 1

# %% [markdown]
# ### Subtitulo para el libro que no tengo :v

# %% [markdown]
# ![reporte4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# # **Hola Humanos Woooooo**

# %% [markdown]
# *¿Y ahora que sucedera en el libro?*

# %% [markdown]
# > ***Hora de programar***
# >> Y weno
# > *¿Es real?*

# %% [markdown]
# ## Lenguaje LaTex/ Markdown

# %% [markdown]
# $$ 5 + 4 = 54 $$
# $$ y=x^2 $$
# $$ \boxed{\frac{2}{3}}$$
# $$\frac{\partial{x}}{\partial{t}} = kC$$

# %%
print("Hello World :'v")
# Out:
# Hello World :'v

# %% [markdown]
# > ## [Recordar editor latex para ecuaciones:](https://www.codecogs.com/latex/eqneditor.php) :D
